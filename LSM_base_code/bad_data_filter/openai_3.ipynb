# %%
import pandas as pd
from tqdm import tqdm

# %%
path = 'data_filter_3.csv'

# %%
from openai import OpenAI # openai==1.52.2

client = OpenAI(
    api_key="",
    base_url="https://api.upstage.ai/v1"
)
def openai_stream(content):
    stream = client.chat.completions.create(
        model="solar-pro2",
        messages=[
            {
                "role": "system",
                "content": content
            }
        ],
        stream=True,
    )
    full_response = ""

    for chunk in stream:
        delta = chunk.choices[0].delta
        if delta.content is not None:
            full_response += delta.content  # 누적 저장

    return full_response

# %%
data = pd.read_csv(path)
output = []
count = 1

pbar = tqdm(total=data['output'].isnull().sum())
for content ,valid_output in data[['prompt','output']].values:
    if pd.isna(valid_output):
        try:
            pbar.update(1)
            count+=1
            result = openai_stream(content)
            output.append(result)
        except Exception as e:
            print(e)
            output.append(None)
    else:
        output.append(valid_output)
    if count%200==0:
        data['output'] = output+([None] * (data.shape[0]-len(output)))
        data.to_csv(path, index=False)
pbar.close()
# Out:
#  22%|██▏       | 224/1038 [36:09<10:56,  1.24it/s]
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
#  24%|██▍       | 248/1038 [36:09<03:40,  3.59it/s]
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
#  26%|██▌       | 272/1038 [36:10<01:34,  8.09it/s]
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
#  27%|██▋       | 284/1038 [36:10<01:04, 11.61it/s]
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
#  30%|██▉       | 307/1038 [36:10<00:34, 21.33it/s]
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
#  32%|███▏      | 330/1038 [36:10<00:19, 36.58it/s]
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
#  34%|███▍      | 354/1038 [36:10<00:12, 56.84it/s]
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# ...
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
#  97%|█████████▋| 1009/1038 [36:16<00:00, 98.70it/s]
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# 100%|█████████▉| 1033/1038 [36:17<00:00, 106.35it/s]
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# 100%|██████████| 1038/1038 [36:17<00:00,  2.10s/it]
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}
# Error code: 401 - {'error': {'message': 'Your API key is invalid. Please verify your API key or generate a new one from our API keys management page (https://console.upstage.ai/api-keys). Remember to keep your API keys secure and never share them publicly', 'type': 'invalid_request_error', 'param': '', 'code': 'invalid_api_key'}}

# %%
data['output'] = output + ([None] * (data.shape[0]-len(output)))
data.to_csv(path, index=False)
